# %%
import kdsource as kds

# %%
track = kds.SurfaceSourceFile("track_Colimador.h5")
# Out:
# Number of particles in file track_Colimador.h5: 229653
# 28% n, 72% g, 0% e-, 0% e+, 0% p,
# /home/agusgimenez/anaconda3/envs/openmc_develop/lib/python3.9/site-packages/kdsource/surfsource.py:437: RuntimeWarning: divide by zero encountered in log10
#   df["log(t)"] = np.log10(df["t"].to_numpy())

# %%
track.get_pandas_dataframe()
# Out:
# /home/agusgimenez/anaconda3/envs/openmc_develop/lib/python3.9/site-packages/kdsource/surfsource.py:437: RuntimeWarning: divide by zero encountered in log10
#   df["log(t)"] = np.log10(df["t"].to_numpy())
#             id  type             E         x         y          z         u  \
# 0            0    22  3.832950e-01  5.130251 -0.745127  69.589378  0.226405
# 1            1    22  1.423350e-01 -5.590899  0.729130  69.589754 -0.091989
# 2            2  2112  3.551810e-08  0.777035 -3.089200  69.589369  0.063570
# 3            3    22  4.991930e+00  1.389698 -5.454100  69.589406  0.009134
# 4            4  2112  4.248890e+00 -4.282019  0.241886  69.589107  0.017673
# ...        ...   ...           ...       ...       ...        ...       ...
# 229648  229648    22  1.544640e+00  6.373277  0.665044  69.589394 -0.692156
# 229649  229649  2112  6.982150e-09 -0.288174 -5.361540  69.589364 -0.350281
# 229650  229650    22  1.161260e+00 -1.275562 -1.994690  69.589371 -0.223508
# ...

# %%
track.save_source_file("track_Colimador_Formated.h5")
# Out:
# Saving into OpenMC format (HDF5)
# Done, saved into track_Colimador_Formated.h5 file

# %%
track.save_source_file("track_Colimador_Formated.mcpl")
# Out:
# Saving into MCPL format
# Saving into SSV format (ASCII)
# Done, saved into temp.txt file
# ssv_open_file: Opened file "temp.txt":
# MCPL: Attempting to compress file track_Colimador_Formated.mcpl with gzip
# MCPL: Succesfully compressed file into track_Colimador_Formated.mcpl.gz
# Created track_Colimador_Formated.mcpl.gz
# Done, saved into track_Colimador_Formated.mcpl file
